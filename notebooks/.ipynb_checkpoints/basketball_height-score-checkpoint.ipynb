# %%
import pandas as pd
import requests
import io
import chardet
import matplotlib.pyplot as plt

# %%
players_url = "https://raw.githubusercontent.com/sjcasey21/linear-relationships/master/datasets/players-seasons/Players.csv"
players_df = pd.read_csv(players_url, names=['player', 'height'])

scores_url = "https://raw.githubusercontent.com/sjcasey21/linear-relationships/master/datasets/players-seasons/Seasons_Stats.csv"
scores_df = pd.read_csv(scores_url, names=['player', 'score'])
scores_df = scores_df.drop_duplicates('player', keep='last')

# %%
df = pd.merge(players_df, scores_df, how='inner')

# %%
# Out:
#                      player  height   score
# 0           Curly Armstrong   180.0   202.0
# 1              Cliff Barker   188.0   126.0
# 2             Leo Barnhorst   193.0   461.0
# 3                Ed Bartels   196.0    72.0
# 4               Ralph Beard   178.0  1111.0
# 5                Gene Berce   180.0    10.0
# 6             Charlie Black   196.0    17.0
# 7               Nelson Bobb   183.0   343.0
# 8           Jake Bornheimer   196.0   254.0
# 9              Vince Boryla   196.0   420.0
# 10                Don Boven   193.0   104.0
# 11            Harry Boykoff   208.0   125.0
# 12              Joe Bradley   190.0    87.0
# 13              Bob Brannum   196.0   442.0
# 14               Carl Braun   196.0   176.0
# 15            Frankie Brian   185.0   228.0
# 16         Price Brookfield   193.0    34.0
# 17                Bob Brown   193.0   724.0
# 18               Jim Browne   208.0    47.0
# 19               Walt Budko   196.0   254.0
# 20           Jack Burmaster   190.0   598.0
# 21             Tommy Byrnes   190.0    87.0
# 22             Bill Calhoun   190.0   454.0
# 23              Don Carlson   183.0    42.0
# 24            Bob Carpenter   196.0   222.0
# 25              Jake Carter   193.0    38.0
# 26                Al Cervi*   180.0   143.0
# 27              John Chaney   190.0    42.0
# 28            Leroy Chollet   188.0    24.0
# 29               Bill Closs   196.0   347.0
# ...                     ...     ...     ...
# 3892         Chinanu Onuaku   208.0    14.0
# 3893   Georgios Papagiannis   216.0   124.0
# 3894            Gary Payton   193.0    20.0
# 3895       Marshall Plumlee   211.0    40.0
# 3896           Jakob Poeltl   213.0   165.0
# 3897         Alex Poythress   201.0    64.0
# 3898         Tim Quarterman   198.0    31.0
# 3899         Chasson Randle   188.0    95.0
# 3900     Malachi Richardson   198.0    79.0
# 3901       Domantas Sabonis   211.0   479.0
# 3902            Dario Saric   208.0  1040.0
# 3903       Tomas Satoransky   201.0   154.0
# 3904           Wayne Selden   196.0    55.0
# 3905          Pascal Siakam   206.0   229.0
# 3906          Diamond Stone   211.0    10.0
# 3907            Edy Tavares   211.0     6.0
# 3908          Isaiah Taylor   190.0     3.0
# 3909             Mike Tobey   213.0     2.0
# 3910             Tyler Ulis   178.0   444.0
# 3911          Jarrod Uthoff   206.0    40.0
# 3912       Denzel Valentine   198.0   291.0
# 3913          Fred VanVleet   183.0   107.0
# 3914  Taurean Waller-Prince   183.0   335.0
# 3915            Okaro White   203.0    98.0
# 3916       Isaiah Whitehead   193.0   543.0
# 3917          Troy Williams   198.0    58.0
# 3918           Kyle Wiltjer   208.0    13.0
# 3919      Stephen Zimmerman   213.0    23.0
# 3920            Paul Zipser   203.0   240.0
# 3921            Ivica Zubac   216.0   284.0
#
# [3922 rows x 3 columns]
