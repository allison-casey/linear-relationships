# %%
import pandas as pd
import requests
import io
import chardet
import matplotlib.pyplot as plt

# %%
url = "https://raw.githubusercontent.com/sjcasey21/linear-relationships/master/datasets/year-lifespan/Year_Lifespan.csv"
df = pd.read_csv(url, names=['year', 'lifespan'])

# %%
df.plot(kind='scatter', x='year', y='lifespan')

# %%
sample=df.sample(10)
sample.plot(kind='scatter', x='year',y='lifespan')

# %%
df
# Out:
#     year  lifespan
# 0   1900     47.30
# 1   1901     49.10
# 2   1902     51.60
# 3   1903     50.55
# 4   1904     47.65
# 5   1905     48.75
# 6   1906     48.85
# 7   1907     47.75
# 8   1908     51.15
# 9   1909     52.15
# 10  1910     50.10
# 11  1911     52.65
# 12  1912     53.70
# 13  1913     52.65
# 14  1914     54.40
# 15  1915     54.65
# 16  1916     51.95
# 17  1917     51.20
# 18  1918     39.40
# 19  1919     54.75
# 20  1920     54.10
# 21  1921     60.90
# 22  1922     59.70
# 23  1923     57.30
# 24  1924     59.80
# 25  1925     59.10
# 26  1926     56.75
# 27  1927     60.55
# 28  1928     56.95
# 29  1929     57.25
# ..   ...       ...
# 69  1969     70.55
# 70  1970     70.90
# 71  1971     71.20
# 72  1972     71.25
# 73  1973     71.45
# 74  1974     72.05
# 75  1975     72.70
# 76  1976     72.95
# 77  1977     73.35
# 78  1978     73.45
# 79  1979     73.90
# 80  1980     73.70
# 81  1981     74.10
# 82  1982     74.45
# 83  1983     74.55
# ...
